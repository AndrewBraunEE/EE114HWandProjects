# %%
#Google speech to text
#The original goal was to see if google text to speech would be good enough in detecting the words / phonemes of each speaker
#And seeing if non-native speakers would confuse a powerful neural net model such as google's speech to text
from google.cloud import speech_v1
from google.cloud.speech_v1 import enums
import io

SCOPE = ["https://www.googleapis.com/auth/cloud-platform"]
SECRETS_FILE = "D:\Repos\EE3EC\Systems-Design-F19\andrew\API_KEY.json"

credentials = SignedJwtAssertionCredentials(json_key['client_email'], json_key['private_key'], SCOPE)

gc = gspread.authorize(credentials)
def sample_recognize(local_file_path, fs):
    """
    Transcribe a short audio file using synchronous speech recognition

    Args:
      local_file_path Path to local audio file, e.g. /path/audio.wav
    """
    
    client = speech_v1.SpeechClient()

    # local_file_path = 'resources/brooklyn_bridge.raw'

    # The language of the supplied audio
    language_code = "en-US"

    # Sample rate in Hertz of the audio data sent
    #sample_rate_hertz = 16000
    sample_rate_hertz = fs
    # Encoding of audio data sent. This sample sets this explicitly.
    # This field is optional for FLAC and WAV audio formats.
    encoding = enums.RecognitionConfig.AudioEncoding.LINEAR16
    config = {
        "language_code": language_code,
        "sample_rate_hertz": sample_rate_hertz,
        "encoding": encoding,
    }
    with io.open(local_file_path, "rb") as f:
        content = f.read()
    audio = {"content": content}

    response = client.recognize(config, audio)
    for result in response.results:
        # First alternative is the most probable result
        alternative = result.alternatives[0]
        print(u"Transcript: {}".format(alternative.transcript))
    return response

# %%
#Doing phoneme speech detection algorithmically
#Takes a wav file, calculates a spectrogram, finds most likely phoneme from our sentence.

#TODO: How do you find most likely phoneme?

import glob, os
import scipy.io, scipy.io.wavfile
import pandas as pd
# %matplotlib inline

import pickle
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt
from python_speech_features import mfcc
from python_speech_features import logfbank

files = glob.glob("../sound_data/*.wav")
data_keys = ['filename', 'f', 't', 'spectrogram', 'fs', 'mfcc_feat', 'fbank_feat', 'label']
list_of_dicts = []
labels = []

for file in files:
    fs, data = scipy.io.wavfile.read(file)
    filename = os.path.basename(file)
    f, t, spectrogram = scipy.signal.spectrogram(data, fs=fs, window='hamming')
    label = 0
    if 'english' in filename:
        label = 1
    labels.append(label)
    mfcc_feat = mfcc(data)
    fbank_feat = logfbank(data)
    data_values = [filename, f, t, spectrogram, fs, mfcc_feat, fbank_feat, label]
    data_dict = dict(zip(data_keys, data_values))
    list_of_dicts.append(data_dict)
    
    print(fbank_feat.shape)
    #text = sample_recognize(file, fs)
    #print(text)
print('File loading complete!')
# Out:
# (5741, 26)
# (6072, 26)
# (7426, 26)
# (3340, 26)
# (9478, 26)
# (7404, 26)
# (4366, 26)
# (7887, 26)
# (6612, 26)
# (6814, 26)
# (7390, 26)
# (6044, 26)
# (5180, 26)
# (5525, 26)
# (6044, 26)
# (4632, 26)
# (5403, 26)
# (6382, 26)
# (6144, 26)
# (6231, 26)
# (5784, 26)
# (6058, 26)
# (8895, 26)
# (6094, 26)
# (7001, 26)
# (5216, 26)
# (4935, 26)
# (5194, 26)
# (6432, 26)
# (6915, 26)
# (6713, 26)
# (5460, 26)
# (6058, 26)
# (5828, 26)
# (5316, 26)
# (5288, 26)
# (5676, 26)
# (5756, 26)
# (5777, 26)
# (5561, 26)
# (5216, 26)
# (6893, 26)
# (7167, 26)
# (6447, 26)
# (6288, 26)
# (6591, 26)
# (7476, 26)
# (5828, 26)
# (4553, 26)
# (9428, 26)
# (5856, 26)
# (8384, 26)
# (5453, 26)
# (6231, 26)
# (7404, 26)
# (5885, 26)
# (7376, 26)
# (6555, 26)
# (6519, 26)
# (5892, 26)
# (6699, 26)
# (8664, 26)
# (7152, 26)
# (6944, 26)
# (6944, 26)
# (6440, 26)
# (8211, 26)
# (6432, 26)
# (6562, 26)
# (6944, 26)
# (6620, 26)
# (7088, 26)
# (7059, 26)
# (5698, 26)
# (8297, 26)
# (6584, 26)
# (7275, 26)
# (4560, 26)
# (6360, 26)
# (5856, 26)
# (6533, 26)
# (5345, 26)
# (6965, 26)
# (7210, 26)
# (5604, 26)
# (6159, 26)
# (7217, 26)
# (6245, 26)
# (5244, 26)
# (6072, 26)
# (7764, 26)
# (8218, 26)
# (12833, 26)
# (8240, 26)
# (13438, 26)
# (9917, 26)
# (4107, 26)
# (7210, 26)
# (7044, 26)
# (7246, 26)
# (3182, 26)
# (6850, 26)
# (7577, 26)
# (5806, 26)
# (6288, 26)
# (5604, 26)
# (6965, 26)
# (7815, 26)
# (11004, 26)
# (6267, 26)
# (9600, 26)
# (5936, 26)
# (7944, 26)
# (7181, 26)
# (11552, 26)
# (8780, 26)
# (9262, 26)
# (5849, 26)
# (6951, 26)
# (5734, 26)
# (7260, 26)
# (6447, 26)
# (7772, 26)
# (6965, 26)
# (11098, 26)
# (8484, 26)
# (9766, 26)
# (6958, 26)
# (6692, 26)
# (8686, 26)
# (7376, 26)
# (6274, 26)
# (6965, 26)
# (8866, 26)
# (6022, 26)
# (5475, 26)
# (10572, 26)
# (11674, 26)
# (8096, 26)
# (8765, 26)
# (5612, 26)
# (7368, 26)
# (9917, 26)
# (10666, 26)
# (7289, 26)
# (6252, 26)
# (6353, 26)
# (8009, 26)
# (7491, 26)
# (6828, 26)
# (4755, 26)
# (6123, 26)
# (6922, 26)
# (6288, 26)
# (7116, 26)
# (6339, 26)
# (6562, 26)
# (13035, 26)
# (11516, 26)
# (10068, 26)
# (6900, 26)
# (4827, 26)
# (11436, 26)
# (10076, 26)
# (9694, 26)
# (6677, 26)
# (8225, 26)
# (10954, 26)
# (8412, 26)
# (7404, 26)
# File loading complete!

# %%
print(list_of_dicts[index]['fbank_feat'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-e57f90c1ec30> in <module>
# ----> 1 print(list_of_dicts[index]['fbank_feat'])
#
# KeyError: 'fbank_feat'

# %%
#Plot some spectrograms
#list_indices = [24, 45, 96, 100, 102]
list_indices = [114, 130, 145, 1, 2, 20, 21, 23]
for index in list_indices:
    plt.pcolormesh(list_of_dicts[index]['t'], list_of_dicts[index]['f'] , list_of_dicts[index]['spectrogram'])
    plt.title('Spectrogram of index: ' + str(index) + ' English Speaker: ' + str(bool(list_of_dicts[index]['filename'])))
    plt.ylabel('Frequency (Hz)')
    plt.xlabel('Time (s)')
    plt.ylim(0, 10000)
    #plt.xlim(0,10)
    plt.show()

plt.title('Filterbank: ' + str(index) + ' English Speaker: ' + str(bool(list_of_dicts[index]['filename'])))
plt.ylabel('Frequency (Hz)')
plt.xlabel('Time (s)')
